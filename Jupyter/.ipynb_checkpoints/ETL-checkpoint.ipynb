# %% [markdown]
# --------------------------- Validação de Dados

# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv("ocorrencia.csv", sep=",", parse_dates=['ocorrencia_dia', 'ocorrencia_hora'], dayfirst=True )
#df.head(10)
#df.tail(n)

# %%
schema = pa.DataFrameSchema(
        columns = {
            "Não_necessária":pa.Column(pa.Int, required = False),
            "codigo_ocorrencia2":pa.Column(pa.Int),      
            "ocorrencia_classificacao":pa.Column(pa.String),
            "ocorrencia_cidade":pa.Column(pa.String),
            "ocorrencia_uf":pa.Column(pa.String, pa.Check.str_length(2,2)),
            "ocorrencia_aerodromo":pa.Column(pa.String),
            "codigo_ocorrencia":pa.Column(pa.Int),
            "ocorrencia_dia":pa.Column(pa.DateTime),
            "ocorrencia_hora":pa.Column(pa.DateTime, nullable = True),
            "total_recomendacoes":pa.Column(pa.Int),
        }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 52242               52242                INCIDENTE
# 1                 45331               45331                 ACIDENTE
# 2                 45333               45333                 ACIDENTE
# 3                 45401               45401                 ACIDENTE
# 4                 45407               45407                 ACIDENTE
# ...                 ...                 ...                      ...
# 5143              80458               80458                 ACIDENTE
# 5144              80452               80452                 ACIDENTE
# 5145              80457               80457          INCIDENTE GRAVE
# 5146              80460               80460                INCIDENTE
# 5147              80467               80467                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         PORTO ALEGRE            RS                 SBPA     2012-01-05
# 1            GUARULHOS            SP                 SBGR     2012-01-06
# 2               VIAMÃO            RS                 ****     2012-01-06
# 3        SÃO SEBASTIÃO            SP                 ****     2012-01-06
# 4             SÃO SEPÉ            RS                 ****     2012-01-06
# ...                ...           ...                  ...            ...
# 5143             JATAÍ            GO                 ####     2021-12-30
# 5144           MARACAÍ            SP                *****     2021-12-31
# 5145     NOVO HAMBURGO            RS                 SSNH     2021-12-31
# 5146          CURITIBA            PR                 SBBI     2021-12-31
# 5147         PETROLINA            PE                 SBPL     2021-12-31
#
#          ocorrencia_hora  total_recomendacoes
# 0    2022-04-12 20:27:00                    0
# 1    2022-04-12 13:44:00                    3
# 2    2022-04-12 13:00:00                    0
# 3    2022-04-12 17:00:00                    0
# 4    2022-04-12 16:30:00                    0
# ...                  ...                  ...
# 5143 2022-04-12 20:30:00                    0
# 5144 2022-04-12 09:30:00                    0
# 5145 2022-04-12 11:59:00                    0
# 5146 2022-04-12 15:12:00                    0
# 5147 2022-04-12 20:30:00                    0
#
# [5148 rows x 9 columns]

# %% [markdown]
# ------------------------------------- Limpeza dos Dados

# %%
df.loc[1:3,'ocorrencia_uf'] #Localizando na matriz ['linha','colina']' nao sao indices de arrays e sim da lista
# Out:
# 1    SP
# 2    RS
# 3    SP
# Name: ocorrencia_uf, dtype: object

# %%
df.loc[[1,500],'ocorrencia_uf'] #Localizando na matriz ['linha','colina']' nao sao indices de arrays e sim da lista
# Out:
# 1      SP
# 500    PR
# Name: ocorrencia_uf, dtype: object

# %%
df.loc[:,'ocorrencia_uf'] #Localizando na matriz ['linha','colina']' nao sao indices de arrays e sim da lista
# Out:
# 0       RS
# 1       SP
# 2       RS
# 3       SP
# 4       RS
#         ..
# 5143    GO
# 5144    SP
# 5145    RS
# 5146    PR
# 5147    PE
# Name: ocorrencia_uf, Length: 5148, dtype: object

# %%
df.codigo_ocorrencia.is_unique #verifica se é unico
# Out:
# True

# %%
if(df.codigo_ocorrencia.is_unique):
    df.set_index('codigo_ocorrencia', inplace = True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# 45331                     GUARULHOS            SP                 SBGR
# 45333                        VIAMÃO            RS                 ****
# 45401                 SÃO SEBASTIÃO            SP                 ****
# 45407                      SÃO SEPÉ            RS                 ****
#
#                   ocorrencia_dia     ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# 52242                 2012-01-05 2022-04-12 20:27:00                    0
# 45331                 2012-01-06 2022-04-12 13:44:00                    3
# 45333                 2012-01-06 2022-04-12 13:00:00                    0
# 45401                 2012-01-06 2022-04-12 17:00:00                    0
# 45407                 2012-01-06 2022-04-12 16:30:00                    0

# %%
df.loc[45407]
# Out:
# codigo_ocorrencia2                        45407
# ocorrencia_classificacao               ACIDENTE
# ocorrencia_cidade                      SÃO SEPÉ
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2012-01-06 00:00:00
# ocorrencia_hora             2022-04-12 16:30:00
# total_recomendacoes                           0
# Name: 45407, dtype: object

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               52242                INCIDENTE      PORTO ALEGRE
# 1               45331                 ACIDENTE         GUARULHOS
# 2               45333                 ACIDENTE            VIAMÃO
# 3               45401                 ACIDENTE     SÃO SEBASTIÃO
# 4               45407                 ACIDENTE          SÃO SEPÉ
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia     ocorrencia_hora  \
# 0            RS                 SBPA     2012-01-05 2022-04-12 20:27:00
# 1            SP                 SBGR     2012-01-06 2022-04-12 13:44:00
# 2            RS                 ****     2012-01-06 2022-04-12 13:00:00
# 3            SP                 ****     2012-01-06 2022-04-12 17:00:00
# 4            RS                 ****     2012-01-06 2022-04-12 16:30:00
#
#    total_recomendacoes
# 0                    0
# 1                    3
# 2                    0
# 3                    0
# 4                    0

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# 45331                     GUARULHOS            SP                 SBGR
# 45333                        VIAMÃO            RS                 ****
# 45401                 SÃO SEBASTIÃO            SP                 ****
# 45407                      SÃO SEPÉ            RS                 ****
#
#                   ocorrencia_dia     ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# 52242                 2012-01-05 2022-04-12 20:27:00                    0
# 45331                 2012-01-06 2022-04-12 13:44:00                    3
# 45333                 2012-01-06 2022-04-12 13:00:00                    0
# 45401                 2012-01-06 2022-04-12 17:00:00                    0
# 45407                 2012-01-06 2022-04-12 16:30:00                    0

# %%
df.loc[df.ocorrencia_aerodromo == '*****', ['ocorrencia_aerodromo']] = ''

# %%
df
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
# ...                               ...                      ...
# 80458                           80458                 ACIDENTE
# 80452                           80452                 ACIDENTE
# 80457                           80457          INCIDENTE GRAVE
# 80460                           80460                INCIDENTE
# 80467                           80467                INCIDENTE
#
#                   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 52242                  PORTO ALEGRE            RS                 SBPA
# 45331                     GUARULHOS            SP                 SBGR
# 45333                        VIAMÃO            RS
# 45401                 SÃO SEBASTIÃO            SP
# 45407                      SÃO SEPÉ            RS
# ...                             ...           ...                  ...
# 80458                         JATAÍ            GO
# 80452                       MARACAÍ            SP
# 80457                 NOVO HAMBURGO            RS                 SSNH
# 80460                      CURITIBA            PR                 SBBI
# 80467                     PETROLINA            PE                 SBPL
#
#                   ocorrencia_dia     ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# 52242                 2012-01-05 2022-04-12 20:27:00                    0
# 45331                 2012-01-06 2022-04-12 13:44:00                    3
# 45333                 2012-01-06 2022-04-12 13:00:00                    0
# 45401                 2012-01-06 2022-04-12 17:00:00                    0
# 45407                 2012-01-06 2022-04-12 16:30:00                    0
# ...                          ...                 ...                  ...
# 80458                 2021-12-30 2022-04-12 20:30:00                    0
# 80452                 2021-12-31 2022-04-12 09:30:00                    0
# 80457                 2021-12-31 2022-04-12 11:59:00                    0
# 80460                 2021-12-31 2022-04-12 15:12:00                    0
# 80467                 2021-12-31 2022-04-12 20:30:00                    0
#
# [5148 rows x 8 columns]
